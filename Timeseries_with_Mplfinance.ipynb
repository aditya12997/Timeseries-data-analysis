# %% [markdown]
# ### In this NoteBook we are using Pandas and MPLFinance to plot our Timeseries Data and Understand the Share Price of Amazon in a Particular period of time.
#
# We are going to see if there was any shift in the curve BEFORE and AFTER COVID-19.
#
# Did the share price really fall?
#
# Was there an Impact as such? Let's see 👀

# %%
import pandas as pd
import mplfinance as mpl

# if you can't access the Mpl library use the command in your notebook as "pip install --upgrade mplfinance"

# %%
df = pd.read_csv("AMZN.csv")
df.head()
# Out:
#          Date    Open         High          Low        Close    Adj Close  \
# 0  2019-12-31  1842.0  1853.260010  1832.229980  1847.839966  1847.839966
# 1  2020-01-02  1875.0  1898.010010  1864.150024  1898.010010  1898.010010
# 2  2020-01-03  1864.5  1886.199951  1864.500000  1874.969971  1874.969971
# 3  2020-01-06  1860.0  1903.689941  1860.000000  1902.880005  1902.880005
# 4  2020-01-07  1904.5  1913.890015  1892.040039  1906.859985  1906.859985
#
#     Volume
# 0  2506500
# 1  4029000
# 2  3764400
# 3  4061800
# 4  4044900

# %% [markdown]
# ### Let's look at our data and it's DataTypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 7 columns):
# Date         522 non-null object
# Open         522 non-null float64
# High         522 non-null float64
# Low          522 non-null float64
# Close        522 non-null float64
# Adj Close    522 non-null float64
# Volume       522 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 28.7+ KB

# %% [markdown]
# As we see that the data column is not indexed and it's in the wrong datatype.
#
# Hence we need to convert it into a datetime series with the help of pandas.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index("Date")

# %%
df.head()
# Out:
#               Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-31  1842.0  1853.260010  1832.229980  1847.839966  1847.839966
# 2020-01-02  1875.0  1898.010010  1864.150024  1898.010010  1898.010010
# 2020-01-03  1864.5  1886.199951  1864.500000  1874.969971  1874.969971
# 2020-01-06  1860.0  1903.689941  1860.000000  1902.880005  1902.880005
# 2020-01-07  1904.5  1913.890015  1892.040039  1906.859985  1906.859985
#
#              Volume
# Date
# 2019-12-31  2506500
# 2020-01-02  4029000
# 2020-01-03  3764400
# 2020-01-06  4061800
# 2020-01-07  4044900

# %% [markdown]
# ### Plotting to data to see how the visuals look like:

# %%
mpl.plot(df)

# %% [markdown]
# ###### The share price for a period of time, as is the definition of Timeseries

# %% [markdown]
# ##### The following way shows how can we plot the price and volume of the shares below for clear understanding of it's performance in a period of time.

# %%
mpl.plot(df, type ='candle', volume =True)

# %% [markdown]
# ### Below we are going to see if there was a unusual dip on the curve or not due to COVID-19
#
#
# Yes, there is a dip in the shareprice when COVID-19 initially affected the whole world

# %%
mpl.plot(df['2020-01':'2020-04'],type ='line',
         figratio =(20,10), volume =True,
         title = "Amazon Share Price before and After COVID-19")

# %% [markdown]
# ### Setting the Moving Average to look for any short-term fluctuations on the price of a stock over a specified time frame are mitigated.

# %%
mpl.plot(df['2020-01':'2020-04'],type ='candle', mav = (20),
         figratio =(20,10), volume =True,
         title = "Amazon Share Price before and After COVID-19", style ="yahoo")

# %% [markdown]
# #### Is it just AMAZON or did it affect other companies as well?
#
# #### Let's have a look at it's competitor: GOOGLE!

# %%
google_df = pd.read_csv("GOOG.csv")
google_df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-12-31  1330.109985  1338.000000  1329.084961  1337.020020
# 1  2020-01-02  1341.550049  1368.140015  1341.550049  1367.369995
# 2  2020-01-03  1347.859985  1372.500000  1345.543945  1360.660034
# 3  2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961
# 4  2020-01-07  1397.939941  1402.989990  1390.380005  1393.339966
#
#      Adj Close   Volume
# 0  1337.020020   961800
# 1  1367.369995  1406600
# 2  1360.660034  1186400
# 3  1394.209961  1732300
# 4  1393.339966  1502700

# %% [markdown]
# ### Same way we will manage this data as well.
#
# #### Changing the Date column type and setting it as our INDEX.

# %%
google_df['Date'] = pd.to_datetime(google_df['Date'])

# %%
google_df = google_df.set_index("Date")

# %%
google_df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-31  1330.109985  1338.000000  1329.084961  1337.020020  1337.020020
# 2020-01-02  1341.550049  1368.140015  1341.550049  1367.369995  1367.369995
# 2020-01-03  1347.859985  1372.500000  1345.543945  1360.660034  1360.660034
# 2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961  1394.209961
# 2020-01-07  1397.939941  1402.989990  1390.380005  1393.339966  1393.339966
#
#              Volume
# Date
# 2019-12-31   961800
# 2020-01-02  1406600
# 2020-01-03  1186400
# 2020-01-06  1732300
# 2020-01-07  1502700

# %%
mpl.plot(google_df['2020-01':'2020-04'],type ='candle',mav =(20),
         figratio =(20,10), volume =True,
         title = "Amazon Share Price before and After COVID-19", style ="yahoo")
